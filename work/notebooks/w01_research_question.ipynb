# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Omar-Alasrag/my-ml-assignment1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Refresh / Content Opportunity Scoring
#
# Why: Teams don't have time to manually check thousands of pages every month. Picking pages randomly or by gut feeling wastes time. We need an automated way to rank high-traffic pages that are dropping, so the team focuses on pages that actually move the needle.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which pages need a refresh review first?
#
# Action: Content editors update thin text, fix outdated info, or align content with actual search intent.
#
# Cost of Error:
#
# False Positive: We waste editor hours updating pages that were fine.
#
# False Negative: Important pages keep losing traffic and revenue without anyone noticing.
#
# Why ML: Rules like "age > 6 months" are too basic. They miss pages losing CTR or position tier. ML lets us combine multiple weak signals into one clean priority rank.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# 54.2% of pages are declining: Over half the dataset is dropping, so page decay is a massive problem here.9,961 high-impression pages need review: 13152 pages have solid search demand but are falling, giving us a huge backlog to prioritize.0.001 correlation: Search volume doesn't predict traffic at all. Static rules won't cut it, so we need a proper multi-signal model.

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

# Quick dataset sanity checks
print("total rows:", len(df))
print("declining pages (%):", (df["trend_direction"] == "down").mean())
print("high-impr declining", len(df[(df["trend_direction"] == "down") & (df["impressions_90d"] >= 100)]))
print("vol vs traffic corr:", round(df["search_volume"].corr(df["impressions_90d"]), 3))
# Out:
# total rows: 30000
# declining pages (%): 0.5420666666666667
# high-impr declining 13152
# vol vs traffic corr: 0.001

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# Can claim: Observational patterns from search data, ranking candidates better than simple rules using Precision@K, and clear reason codes for each page.
#
# Cannot claim: Proof of Google algorithm updates, or guaranteed traffic recovery after a refresh (since competitors and SERP changes are outside the dataset).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
